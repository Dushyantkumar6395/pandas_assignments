# %%
import pandas as pd

# %%
df = pd.read_csv("data2.csv")

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3   Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income  monthly_sal
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'email_id', 'phone_number', 'Sex', 'Civil_code',
#        'income', 'monthly_sal'],
#       dtype='object')

# %%
df.head()
# Out:
#              Name         Address            email_id  phone_number     Sex  \
# 0  Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1  Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2  Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3  Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4  Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
#
#    Civil_code  income  monthly_sal
# 0           1       1            1
# 1           2       2            8
# 2           3       1            8
# 3           4       4            7
# 4           5       4            6

# %%
df.drop("monthly_sal", axis = 1) # not permamentally change
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3   Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# ...

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3   Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income  monthly_sal
# ...

# %%
df.drop("monthly_sal", axis = 1,inplace = True)  # This is delete permanentally

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3   Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# ...

# %%
df.drop(3)
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# 0            1       1
# 1            2       2
# 2            3       1
# 4            5       4
# ...

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 3   Eushyant kumar  Eaithra Aalpur  eushyant@gmail.com    4395928960  Female
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# ...

# %%
df.drop(3,inplace = True)

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# 0            1       1
# 1            2       2
# 2            3       1
# 4            5       4
# ...

# %%
df.set_index("Name")
# Out:
#                        Address            email_id  phone_number     Sex  \
# Name
# Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#                 Civil_code  income
# Name
# Dushyant kumar           1       1
# Bushyant kumar           2       2
# Cushyant kumar           3       1
# ...

# %%
df
# Out:
#               Name         Address            email_id  phone_number     Sex  \
# 0   Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960    Male
# 1   Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960  Female
# 2   Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960    Male
# 4   Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960    Male
# 5   Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960    Male
# 6   Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960  Female
# 7   Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960    Male
# 8   Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960  Female
# 9   Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960    Male
# 10  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960    Male
#
#     Civil_code  income
# 0            1       1
# 1            2       2
# 2            3       1
# 4            5       4
# ...

# %%
df.set_index("income", inplace = True)

# %%
df
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 8       Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 1       Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#            Sex  Civil_code
# income
# 1         Male           1
# 2       Female           2
# 1         Male           3
# 4         Male           5
# ...

# %%
df.reset_index()
# Out:
#    income            Name         Address            email_id  phone_number  \
# 0       1  Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 1       2  Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 2       1  Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 3       4  Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 4       9  Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 5       8  Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 6       3  Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 7       1  Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 8       5  Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 9       8  Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#       Sex  Civil_code
# 0    Male           1
# 1  Female           2
# 2    Male           3
# 3    Male           5
# ...

# %%
d = {
    "key1": [3,4,5,6,7],
    "key2": [5,6,7,8,6],
    "key3": [4,5,6,7,8]
}

# %%
df1=pd.DataFrame(d)

# %%
df1
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.read_csv("Reliance.csv")

# %%
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
# df2.dropna()  # This is use only when then remove those row and column whose any row and any column has no data

# %%
df2.dropna()
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df2.dropna(inplace = True)

# %%
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df2.dropna(axis=1,inplace = True)

# %%
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df3 = pd.read_csv("playres_data.csv")

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df3.dropna(axis=1)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  FTA  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  1.4  1.2
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  0.8  0.3
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  2.9  2.8
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  2.2  1.4
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  2.5  0.3
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...  ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  2.6  1.7
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  2.7  1.6
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  2.5  1.9
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  2.6  1.6
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  2.3  1.8
#
# ...

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df3.fillna("Dushyant")
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 8       Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 1       Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#            Sex  Civil_code
# income
# 1         Male           1
# 2       Female           2
# 1         Male           3
# 4         Male           5
# ...

# %%
df1
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#    index  key1  key2  key3
# 0      0     3     5     4
# 1      1     4     6     5
# 2      2     5     7     6
# 3      3     6     8     7
# 4      4     7     6     8

# %%
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1     2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2     2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3     2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4     2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...          ...          ...          ...          ...          ...
# 1228  2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229  2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230  2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231  2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232  2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
g = df.groupby('Sex')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_84/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#         phone_number  Civil_code
# Sex
# Female   19187786880          18
# Male     39771502720          44

# %%
g.mean()
# Out:
# /tmp/ipykernel_84/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#         phone_number  Civil_code
# Sex
# Female  6.395929e+09    6.000000
# Male    5.681643e+09    6.285714

# %%
g1 = df.groupby('income')

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_84/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         phone_number  Civil_code
# income
# 1        19187786880          13
# 2         2395928960           2
# 3         8395928960           8
# 4         5395928960           5
# 5         3395928960          10
# 8        13791857920          18
# 9         6395928960           6

# %%
g1.max()
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Lushyant kumar  Maithra Aalpur  lushyant@gmail.com    9395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    7395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
#
#            Sex  Civil_code
# income
# 1         Male           9
# 2       Female           2
# 3         Male           8
# 4         Male           5
# 5         Male          10
# 8         Male          11
# 9         Male           6

# %%
g1.mean()
# Out:
# /tmp/ipykernel_84/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         phone_number  Civil_code
# income
# 1       6.395929e+09    4.333333
# 2       2.395929e+09    2.000000
# 3       8.395929e+09    8.000000
# 4       5.395929e+09    5.000000
# 5       3.395929e+09   10.000000
# 8       6.895929e+09    9.000000
# 9       6.395929e+09    6.000000

# %%
g1.max().T
# Out:
# income                         1                   2                   3  \
# Name              Lushyant kumar      Bushyant kumar      Kushyant kumar
# Address           Maithra Aalpur      Baithra Aalpur      Kaithra Aalpur
# email_id      lushyant@gmail.com  bushyant@gmail.com  kushyant@gmail.com
# phone_number          9395928960          2395928960          8395928960
# Sex                         Male              Female                Male
# Civil_code                     9                   2                   8
#
# income                         4                   5                   8  \
# Name              Rushyant kumar      Sushyant kumar      Qushyant kumar
# Address           Raithra Aalpur      Saithra Aalpur      Qaithra Aalpur
# email_id      rushyant@gmail.com  sushyant@gmail.com  qushyant@gmail.com
# phone_number          5395928960          3395928960          7395928960
# Sex                         Male                Male                Male
# ...

# %%
g1.max().transpose()
# Out:
# income                         1                   2                   3  \
# Name              Lushyant kumar      Bushyant kumar      Kushyant kumar
# Address           Maithra Aalpur      Baithra Aalpur      Kaithra Aalpur
# email_id      lushyant@gmail.com  bushyant@gmail.com  kushyant@gmail.com
# phone_number          9395928960          2395928960          8395928960
# Sex                         Male              Female                Male
# Civil_code                     9                   2                   8
#
# income                         4                   5                   8  \
# Name              Rushyant kumar      Sushyant kumar      Qushyant kumar
# Address           Raithra Aalpur      Saithra Aalpur      Qaithra Aalpur
# email_id      rushyant@gmail.com  sushyant@gmail.com  qushyant@gmail.com
# phone_number          5395928960          3395928960          7395928960
# Sex                         Male                Male                Male
# ...

# %%
df
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 8       Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 1       Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#            Sex  Civil_code
# income
# 1         Male           1
# 2       Female           2
# 1         Male           3
# 4         Male           5
# ...

# %%
df5 = df[['Name', 'Address' , 'Sex']][0:5]

# %%
df6 = df[['Name', 'Address' , 'Sex']][0:6]

# %%
df5
# Out:
#                   Name         Address     Sex
# income
# 1       Dushyant kumar  Maithra Aalpur    Male
# 2       Bushyant kumar  Baithra Aalpur  Female
# 1       Cushyant kumar  Caithra Aalpur    Male
# 4       Rushyant kumar  Raithra Aalpur    Male
# 9       Fushyant kumar  Faithra Aalpur    Male

# %%
df6
# Out:
#                   Name         Address     Sex
# income
# 1       Dushyant kumar  Maithra Aalpur    Male
# 2       Bushyant kumar  Baithra Aalpur  Female
# 1       Cushyant kumar  Caithra Aalpur    Male
# 4       Rushyant kumar  Raithra Aalpur    Male
# 9       Fushyant kumar  Faithra Aalpur    Male
# 8       Jushyant kumar  Jaithra Aalpur  Female

# %%
df7 = pd.concat([df5,df6])

# %%
df7.fillna('sudh')
# Out:
#                   Name         Address     Sex
# income
# 1       Dushyant kumar  Maithra Aalpur    Male
# 2       Bushyant kumar  Baithra Aalpur  Female
# 1       Cushyant kumar  Caithra Aalpur    Male
# 4       Rushyant kumar  Raithra Aalpur    Male
# 9       Fushyant kumar  Faithra Aalpur    Male
# 1       Dushyant kumar  Maithra Aalpur    Male
# 2       Bushyant kumar  Baithra Aalpur  Female
# 1       Cushyant kumar  Caithra Aalpur    Male
# 4       Rushyant kumar  Raithra Aalpur    Male
# 9       Fushyant kumar  Faithra Aalpur    Male
# 8       Jushyant kumar  Jaithra Aalpur  Female

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                    'key2': [4,5,6,7,8],
                    'key3': [3,4,5,6,6]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2 = pd.DataFrame({'key1':[1,2,45,6,67],
                    'key2': [56,5,6,7,8],
                    'key3': [3,56,5,6,6]

})

# %%
data2
# Out:
#    key1  key2  key3
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key2  key3
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1,data2)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1,data2,how = 'outer', on = 'key1')
# Out:
#    key1  key2_x  key3_x  key2_y  key3_y
# 0     1     4.0     3.0    56.0     3.0
# 1     2     5.0     4.0     5.0    56.0
# 2     4     6.0     5.0     NaN     NaN
# 3     5     7.0     6.0     NaN     NaN
# 4     6     8.0     6.0     7.0     6.0
# 5    45     NaN     NaN     6.0     5.0
# 6    67     NaN     NaN     8.0     6.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2_x  key3_x  key1_y  key2_y  key3_y
# 0        1       4       3       1      56       3
# 1        1       4       3       2       5      56
# 2        1       4       3      45       6       5
# 3        1       4       3       6       7       6
# 4        1       4       3      67       8       6
# 5        2       5       4       1      56       3
# 6        2       5       4       2       5      56
# 7        2       5       4      45       6       5
# 8        2       5       4       6       7       6
# 9        2       5       4      67       8       6
# 10       4       6       5       1      56       3
# 11       4       6       5       2       5      56
# 12       4       6       5      45       6       5
# 13       4       6       5       6       7       6
# 14       4       6       5      67       8       6
# 15       5       7       6       1      56       3
# 16       5       7       6       2       5      56
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                    'key2': [4,5,6,7,8],
                    'key3': [3,4,5,6,6]},
                     index = ['a','b', 'c', 'd', 'e']
                     
                     )

# %%
data2 = pd.DataFrame({'key11':[1,2,45,6,67],
                    'key22': [56,5,6,7,8],
                    'key33': [3,56,5,6,6]

},index = ['a','b','h','i','j'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %% [markdown]
# #### data2

# %%
data2
# Out:
#    key11  key22  key33
# a      1     56      3
# b      2      5     56
# h     45      6      5
# i      6      7      6
# j     67      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0   56.0    3.0
# b     2     5     4    2.0    5.0   56.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2, how = 'right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1     56      3
# b   2.0   5.0   4.0      2      5     56
# h   NaN   NaN   NaN     45      6      5
# i   NaN   NaN   NaN      6      7      6
# j   NaN   NaN   NaN     67      8      6

# %%
data1.join(data2, how = 'inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1     56      3
# b     2     5     4      2      5     56

# %%
data1.join(data2, how = 'outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0   56.0    3.0
# b   2.0   5.0   4.0    2.0    5.0   56.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN   45.0    6.0    5.0
# i   NaN   NaN   NaN    6.0    7.0    6.0
# j   NaN   NaN   NaN   67.0    8.0    6.0

# %%
data1.join(data2, how = 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1     56      3
# 1      1     4     3      2      5     56
# 2      1     4     3     45      6      5
# 3      1     4     3      6      7      6
# 4      1     4     3     67      8      6
# 5      2     5     4      1     56      3
# 6      2     5     4      2      5     56
# 7      2     5     4     45      6      5
# 8      2     5     4      6      7      6
# 9      2     5     4     67      8      6
# 10     4     6     5      1     56      3
# 11     4     6     5      2      5     56
# 12     4     6     5     45      6      5
# 13     4     6     5      6      7      6
# 14     4     6     5     67      8      6
# 15     5     7     6      1     56      3
# 16     5     7     6      2      5     56
# 17     5     7     6     45      6      5
# 18     5     7     6      6      7      6
# 19     5     7     6     67      8      6
# 20     6     8     6      1     56      3
# ...

# %%
df
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 8       Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 1       Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#            Sex  Civil_code
# income
# 1         Male           1
# 2       Female           2
# 1         Male           3
# 4         Male           5
# ...

# %%
df['Civil_code_INR'] = df['Civil_code'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
#
#            Sex  Civil_code  Civil_code_INR
# income
# 1         Male           1              80
# 2       Female           2             160
# 1         Male           3             240
# 4         Male           5             400
# 9         Male           6             480

# %%
def euro_inr(x):
    return x*80
df['Civil_code_INR'] = df['Civil_code'].apply(euro_inr)

# %%
df.head()
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
#
#            Sex  Civil_code  Civil_code_INR
# income
# 1         Male           1              80
# 2       Female           2             160
# 1         Male           3             240
# 4         Male           5             400
# 9         Male           6             480

# %%
df['Name_length'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
#
#            Sex  Civil_code  Civil_code_INR  Name_length
# income
# 1         Male           1              80           14
# 2       Female           2             160           14
# 1         Male           3             240           14
# 4         Male           5             400           14
# 9         Male           6             480           14

# %%
def cat_Civil_code(x):
    if x<5:
        return "cheap"
    elif x>=5 and x<8:
        return "mid"
    else:
        return "high"
    
df['Cat_Civil_code'] = df['Civil_code'].apply(cat_Civil_code)

# %%
df.head()
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
#
#            Sex  Civil_code  Civil_code_INR  Name_length Cat_Civil_code
# income
# 1         Male           1              80           14          cheap
# 2       Female           2             160           14          cheap
# 1         Male           3             240           14          cheap
# 4         Male           5             400           14            mid
# 9         Male           6             480           14            mid

# %%
df
# Out:
#                   Name         Address            email_id  phone_number  \
# income
# 1       Dushyant kumar  Maithra Aalpur  dushyant@gmail.com    6395928960
# 2       Bushyant kumar  Baithra Aalpur  bushyant@gmail.com    2395928960
# 1       Cushyant kumar  Caithra Aalpur  cushyant@gmail.com    3395928960
# 4       Rushyant kumar  Raithra Aalpur  rushyant@gmail.com    5395928960
# 9       Fushyant kumar  Faithra Aalpur  fushyant@gmail.com    6395928960
# 8       Jushyant kumar  Jaithra Aalpur  jushyant@gmail.com    7395928960
# 3       Kushyant kumar  Kaithra Aalpur  kushyant@gmail.com    8395928960
# 1       Lushyant kumar  Laithra Aalpur  lushyant@gmail.com    9395928960
# 5       Sushyant kumar  Saithra Aalpur  sushyant@gmail.com    3395928960
# 8       Qushyant kumar  Qaithra Aalpur  qushyant@gmail.com    6395928960
#
#            Sex  Civil_code  Civil_code_INR  Name_length Cat_Civil_code
# income
# 1         Male           1              80           14          cheap
# ...
