# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("data.csv")

# %%
df.head()  # this is look starting five row by default
# Out:
#        name           emaoil_id  phone_number
# 0  Dushyant  dushyank@gmail.com    6395928960
# 1     Harry     harry@gmail.com    6402357853

# %%
df.head(1)
# Out:
#        name           emaoil_id  phone_number
# 0  Dushyant  dushyank@gmail.com    6395928960

# %%
df.tail() # this is look last five row by default
# Out:
#        name           emaoil_id  phone_number
# 0  Dushyant  dushyank@gmail.com    6395928960
# 1     Harry     harry@gmail.com    6402357853

# %%
df.tail(1)
# Out:
#     name        emaoil_id  phone_number
# 1  Harry  harry@gmail.com    6402357853

# %%
df.tail(2)
# Out:
#        name           emaoil_id  phone_number
# 0  Dushyant  dushyank@gmail.com    6395928960
# 1     Harry     harry@gmail.com    6402357853

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['name', 'emaoil_id', 'phone_number']

# %%
df['name']
# Out:
# 0    Dushyant
# 1       Harry
# Name: name, dtype: object

# %%
df['emaoil_id']
# Out:
# 0    dushyank@gmail.com
# 1       harry@gmail.com
# Name: emaoil_id, dtype: object

# %%
df['phone_number']
# Out:
# 0    6395928960
# 1    6402357853
# Name: phone_number, dtype: int64

# %%
list(df['phone_number'])
# Out:
# [6395928960, 6402357853]

# %%
type(df[['phone_number']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['phone_number'])
# Out:
# pandas.core.series.Series

# %%
df[['name', 'emaoil_id']]
# Out:
#        name           emaoil_id
# 0  Dushyant  dushyank@gmail.com
# 1     Harry     harry@gmail.com

# %%
df[['name', 'emaoil_id', 'phone_number']]
# Out:
#        name           emaoil_id  phone_number
# 0  Dushyant  dushyank@gmail.com    6395928960
# 1     Harry     harry@gmail.com    6402357853

# %%
df.dtypes
# Out:
# name            object
# emaoil_id       object
# phone_number     int64
# dtype: object

# %%
df1 = pd.read_excel("Book1.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# House Age (years)               float64
# Distance to Station (meters)    float64
# Price per Square Foot           float64
# Unnamed: 3                      float64
# Sum                              object
# dtype: object

# %%
df1.columns
# Out:
# Index(['House Age (years)', 'Distance to Station (meters)',
#        'Price per Square Foot', 'Unnamed: 3', 'Sum'],
#       dtype='object')

# %%
list(df1.columns)
# Out:
# ['House Age (years)',
#  'Distance to Station (meters)',
#  'Price per Square Foot',
#  'Unnamed: 3',
#  'Sum']

# %%
df1[['House Age (years)','Distance to Station (meters)']]
# Out:
#     House Age (years)  Distance to Station (meters)
# 0                32.0                      84.87882
# 1                19.5                     306.59470
# 2                13.3                     561.98450
# 3                13.3                     561.98450
# 4                 5.0                     390.56840
# 5                 7.1                    2175.03000
# 6                34.5                     623.47310
# 7                20.3                     287.60250
# 8                31.7                    5512.03800
# 9                17.9                    1783.18000
# 10               34.8                     405.21340
# 11                6.3                      90.45606
# 12               13.0                     492.23130
# 13               20.4                    2469.64500
# 14               13.2                    1164.83800
# 15               35.7                     579.20830
# 16                0.0                     292.99780
# ...

# %%
df1.head()
# Out:
#    House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 0               32.0                      84.87882                   75.8
# 1               19.5                     306.59470                   84.4
# 2               13.3                     561.98450                   94.6
# 3               13.3                     561.98450                  109.6
# 4                5.0                     390.56840                   86.2
#
#    Unnamed: 3            Sum
# 0         NaN           Mean
# 1         NaN         Median
# 2         NaN           Mode
# 3         NaN  St. Deviation
# 4         NaN       Variance

# %%
df1.columns
# Out:
# Index(['House Age (years)', 'Distance to Station (meters)',
#        'Price per Square Foot', 'Unnamed: 3', 'Sum'],
#       dtype='object')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1['House Age (years)']
# Out:
# 0     32.0
# 1     19.5
# 2     13.3
# 3     13.3
# 4      5.0
# 5      7.1
# 6     34.5
# 7     20.3
# 8     31.7
# 9     17.9
# 10    34.8
# 11     6.3
# 12    13.0
# 13    20.4
# 14    13.2
# 15    35.7
# 16     0.0
# 17    17.7
# 18    16.9
# 19     1.5
# 20     4.5
# 21    10.5
# 22    14.7
# 23    10.1
# 24    39.6
# 25    29.3
# 26     3.1
# 27    10.4
# 28    19.2
# 29     7.1
# 30    25.9
# 31    29.6
# 32    37.9
# 33    16.5
# 34    15.4
# 35    13.9
# 36    14.7
# 37    12.0
# 38     3.1
# 39    16.2
# 40    13.6
# 41    16.8
# 42    36.1
# 43    34.4
# 44     2.7
# 45    36.6
# 46    21.7
# 47    35.9
# 48    24.2
# 49    29.4
# Name: House Age (years), dtype: float64

# %%
df1[['House Age (years)','Distance to Station (meters)']]
# Out:
#     House Age (years)  Distance to Station (meters)
# 0                32.0                      84.87882
# 1                19.5                     306.59470
# 2                13.3                     561.98450
# 3                13.3                     561.98450
# 4                 5.0                     390.56840
# 5                 7.1                    2175.03000
# 6                34.5                     623.47310
# 7                20.3                     287.60250
# 8                31.7                    5512.03800
# 9                17.9                    1783.18000
# 10               34.8                     405.21340
# 11                6.3                      90.45606
# 12               13.0                     492.23130
# 13               20.4                    2469.64500
# 14               13.2                    1164.83800
# 15               35.7                     579.20830
# 16                0.0                     292.99780
# ...

# %%
type(df1['House Age (years)'])
# Out:
# pandas.core.series.Series

# %%
type(df1[['House Age (years)']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.tail()
# Out:
#     House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 45               36.6                      488.8193                   76.6
# 46               21.7                      463.9623                   84.0
# 47               35.9                      640.7391                  123.0
# 48               24.2                     4605.7490                   26.8
# 49               29.4                     4510.3590                   26.4
#
#     Unnamed: 3  Sum
# 45         NaN  NaN
# 46         NaN  NaN
# 47         NaN  NaN
# 48         NaN  NaN
# 49         NaN  NaN

# %%
# df2 = pd.read_csv("url_any_website")

# %%
# df2.head(3)

# %%
#df2.columns

# %%
# type(df2)

# %%
# df2['column']

# %%
# type(df2['column'])

# %%
# df2[["multiple_column"]]

# %%
# df2.tail()

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_per_game.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_per_game.html")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 61.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import lxml
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_per_game.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 = url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784  1.2
# 1  2   Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609  0.3
# 2  3   Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502  2.8
# 3  4    Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579  1.4
# 4  5  Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843  0.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 30 columns]

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 670  1.7  3.7  5.4  2.3  1.6  0.3  1.5  2.3  14.1
# 671  1.6  3.5  5.1  2.8  1.8  0.4  1.6  2.4  14.3
# 672  1.9  4.1  5.9  1.4  1.4  0.3  1.5  2.0  13.8
# 673  1.6  4.3  5.8  1.6  0.5  0.8  1.0  2.5   7.6
# 674  1.8  3.9  5.7  1.4  0.2  0.6  0.9  2.5  10.2
#
# [5 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[['Pos', 'Age', 'Tm']]
# Out:
#     Pos Age   Tm
# 0    PF  24  NYK
# 1    SG  20  MEM
# 2     C  21  OKC
# 3    PF  28  MIN
# 4    SG  29  TOT
# ..   ..  ..  ...
# 670  PF  26  TOT
# 671  PF  26  MIN
# 672  PF  26  BRK
# 673   C  22  CHO
# 674   C  25  BOS
#
# [675 rows x 3 columns]

# %%
df3.to_csv("playres_data.csv", index = False)
